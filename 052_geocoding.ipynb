# %%
# !pip install geocoder
import geocoder
# Out:
# ...
#      |████████████████████████████████| 98 kB 2.5 MB/s
# ...

# %%
from google.colab import files
# Create data on to Google Drive
from google.colab import drive
# Mount your Drive to the Colab VM.
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
with open("/gdrive/MyDrive/06_ai/assets/gay-seattle-places-geocoded.csv", "w", encoding="utf8") as geofp:
    geofp.write("name, frequency, lat, lng\n")
    with open("/gdrive/MyDrive/06_ai/assets/gay-seattle-places.csv", "r", encoding="utf8") as fp:
        for line in fp.readlines():
            location = line.split(",")[0]
            freq = int(line.split(",")[1])
            try:
                g = geocoder.arcgis(location)
                lat = g.current_result.lat
                lng = g.current_result.lng
                geofp.write("%s, %d, %f, %f\n" % (location, freq, lat, lng))
                print(location, freq, lat, lng)
            except:
                pass
print("finished!")
# Out:
# seattle 1296 47.60357000000005 -122.32944999999995
# washington 444 38.890370000000075 -77.03195999999997
# france 90 46.55941704400004 2.5505399530000545
# newyork 90 56.25000000000006 -5.283329999999978
# sanfrancisco 70 -8.98345999999998 -38.21677999999997
# rome 50 41.90322000000003 12.495650000000069
# vatican 46 41.90225000000004 12.45330000000007
# california 44 36.37410569300005 -119.27022999999997
# hollywood 40 26.01067000000006 -80.16025999999994
# king county 34 47.490118504000066 -121.80433656399998
# tacoma 34 47.255130000000065 -122.44163999999995
# oregon 32 43.938780241000075 -120.55856091199996
# united states 30 39.39870315600007 -99.41461918999994
# vietnam 24 16.166670000000067 107.83333000000005
# chicago 22 41.884250000000065 -87.63244999999995
# losangeles 20 34.053570000000036 -118.24544999999995
# america 18 39.39870315600007 -99.41461918999994
# newyork city 16 22.640870000000064 75.84844000000004
# olympia 15 47.03956000000005 -122.89165999999994
# ...
